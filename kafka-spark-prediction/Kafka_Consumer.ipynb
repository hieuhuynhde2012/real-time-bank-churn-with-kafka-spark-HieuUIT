# %%
import pyspark
from pyspark.sql import SparkSession

# Kiểm tra và thiết lập phiên bản Scala và Spark
scala_version = '2.12'
spark_version = '3.2.1'

# Gói cần thiết cho Spark Kafka
packages = [
    f'org.apache.spark:spark-sql-kafka-0-10_{scala_version}:{spark_version}',
    'org.apache.kafka:kafka-clients:3.0.0'  # Thay bằng phiên bản Kafka client tương thích
]

spark = SparkSession.builder \
    .master("local") \
    .appName("ChurnPredictionStreaming") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.2.1") \
    .config("spark.driver.extraJavaOptions", "-Dlog4j.debug=true") \
    .config("spark.executor.extraJavaOptions", "-Dlog4j.debug=true") \
    .getOrCreate()


# Hiển thị thông tin SparkSession
print(spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x000002249B193AF0>

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, from_json
from pyspark.sql.types import StructType, StructField, IntegerType, DoubleType
from pyspark.ml.classification import LogisticRegressionModel
from pyspark.ml.feature import VectorAssembler
from kafka import KafkaProducer
import json

# %%
# Định nghĩa schema của dữ liệu nhận từ Kafka
schema = StructType([
    StructField("CustomerId", IntegerType(), True),  # Giữ lại CustomerId để nhận diện khách hàng
    StructField("CreditScore", IntegerType(), True),
    StructField("Geography", IntegerType(), True),  # Đã được mã hóa (France:0, Spain:1, Germany:2)
    StructField("Gender", IntegerType(), True),  # Đã được mã hóa (Male:0, Female:1)
    StructField("Age", IntegerType(), True),
    StructField("Tenure", IntegerType(), True),
    StructField("Balance", DoubleType(), True),
    StructField("NumOfProducts", IntegerType(), True),
    StructField("HasCrCard", IntegerType(), True),
    StructField("IsActiveMember", IntegerType(), True),
    StructField("EstimatedSalary", DoubleType(), True)
])

# %%
# topic_name = 'transactions'
# kafka_server = 'localhost:9092'
# kafkaDf = spark.read.format("kafka").option("kafka.bootstrap.servers", kafka_server).option("subscribe", topic_name).option("startingOffsets",
# "earliest").load()

# %%
df_stream = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "transactions") \
    .option("startingOffsets", "earliest") \
    .option("failOnDataLoss", "false") \
    .load()

# %%
# Giải mã dữ liệu JSON từ Kafka
df_parsed = df_stream.selectExpr("CAST(value AS STRING)") \
    .select(from_json(col("value"), schema).alias("data")) \
    .select("data.*")

# Load mô hình đã huấn luyện từ thư mục 'output/bestmodel'
model = LogisticRegressionModel.load("C:/Users/PC/Desktop/Do_an_Big_data/PythonCodes/output/bestModel")

# %%
# # Chuyển đổi dữ liệu đầu vào thành vector feature
# feature_columns = ["CreditScore", "Geography", "Gender", "Age", "Tenure", 
#                    "Balance", "NumOfProducts", "HasCrCard", "IsActiveMember", "EstimatedSalary"]
# assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
# df_features = assembler.transform(df_parsed)

# # Dự đoán churn (0: giữ chân, 1: rời bỏ)
# df_predictions = model.transform(df_features)

# # Chọn dữ liệu đầu ra bao gồm CustomerId và dự đoán
# df_results = df_predictions.select("CustomerId", col("prediction").alias("ChurnPrediction"))

# # Gửi kết quả dự đoán về Kafka topic 'churn_predictions'
# producer = KafkaProducer(bootstrap_servers='localhost:9092',
#                          value_serializer=lambda v: json.dumps(v).encode('utf-8'))

# # Xử lý từng batch và gửi dữ liệu về Kafka
# def send_to_kafka(batch_df, batch_id):
#     records = batch_df.collect()
#     for row in records:
#         message = {"CustomerId": row.CustomerId, "ChurnPrediction": int(row.ChurnPrediction)}
#         producer.send("churn_predictions", value=message)
#         print(f"Sent to Kafka: {message}")

# # Ghi kết quả dự đoán ra Kafka
# query = df_results.writeStream \
#     .foreachBatch(send_to_kafka) \
#     .outputMode("append") \
#     .start()

# query.awaitTermination()

# %%
# Chuyển đổi dữ liệu đầu vào thành vector feature
feature_columns = ["CreditScore", "Geography", "Gender", "Age", "Tenure", 
                   "Balance", "NumOfProducts", "HasCrCard", "IsActiveMember", "EstimatedSalary"]
assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")
df_features = assembler.transform(df_parsed)

# Dự đoán churn (0: giữ chân, 1: rời bỏ)
df_predictions = model.transform(df_features)
# Chọn tất cả đặc trưng đầu vào cùng với kết quả dự đoán
df_results = df_predictions.select(
    "CustomerId", "CreditScore", "Geography", "Gender", "Age", "Tenure", 
    "Balance", "NumOfProducts", "HasCrCard", "IsActiveMember", "EstimatedSalary",
    col("prediction").alias("ChurnPrediction")
)

# Gửi kết quả dự đoán về Kafka topic 'churn_predictions'
producer = KafkaProducer(bootstrap_servers='localhost:9092',
                         value_serializer=lambda v: json.dumps(v).encode('utf-8'))

# Xử lý từng batch và gửi dữ liệu về Kafka
def send_to_kafka(batch_df, batch_id):
    # Hiển thị batch DataFrame trên Jupyter Notebook
    print(f"Batch {batch_id}:")
    batch_df.show(truncate=False)  # Hiển thị toàn bộ dữ liệu
    
    # Chuyển DataFrame thành danh sách từ điển
    records = batch_df.collect()
    for row in records:
        message = {
            "CustomerId": row.CustomerId,
            "CreditScore": row.CreditScore,
            "Geography": row.Geography,
            "Gender": row.Gender,
            "Age": row.Age,
            "Tenure": row.Tenure,
            "Balance": row.Balance,
            "NumOfProducts": row.NumOfProducts,
            "HasCrCard": row.HasCrCard,
            "IsActiveMember": row.IsActiveMember,
            "EstimatedSalary": row.EstimatedSalary,
            "ChurnPrediction": int(row.ChurnPrediction)
        }
        producer.send("churn_predictions", value=message)
        print(f"Sent to Kafka: {message}")

# Ghi kết quả dự đoán ra Kafka và hiển thị lên console
query = df_results.writeStream \
    .foreachBatch(send_to_kafka) \
    .outputMode("append") \
    .start()

query.awaitTermination()
# Out:
# Batch 0:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |87533838  |462        |0        |1     |65 |2     |62606.45 |2            |1        |0             |66910.92       |1.0            |
# |13514980  |614        |0        |1     |23 |5     |49103.8  |1            |1        |1             |182883.44      |1.0            |
# |76449385  |505        |0        |1     |31 |4     |205059.78|2            |1        |1             |12350.26       |0.0            |
# |41040408  |363        |0        |0     |62 |2     |40101.19 |2            |0        |1             |160262.94      |1.0            |
# |49519398  |582        |2        |0     |62 |4     |219977.02|1            |0        |0             |119449.28      |1.0            |
# |99598380  |726        |1        |0     |66 |8     |237201.15|1            |0        |0             |89849.54       |1.0            |
# |25889310  |708        |2        |0     |51 |3     |243046.79|2            |1        |1             |68309.95       |1.0            |
# |20273885  |425        |1        |0     |19 |7     |29737.31 |1            |1        |0             |31955.93       |1.0            |
# |26306118  |752        |1        |0     |49 |10    |141197.79|3            |0        |1             |161599.28      |1.0            |
# |87825317  |475        |2        |1     |63 |6     |149286.19|4            |1        |0             |160950.81      |1.0            |
# |69702400  |389        |2        |1     |25 |3     |234800.23|1            |1        |1             |78881.05       |1.0            |
# |68817522  |738        |1        |0     |18 |4     |98946.94 |2            |0        |1             |68981.8        |1.0            |
# |88967499  |530        |0        |0     |25 |3     |210612.31|4            |1        |1             |57463.11       |1.0            |
# |80441991  |848        |2        |1     |53 |6     |46749.36 |4            |0        |0             |188510.67      |1.0            |
# |82902337  |491        |0        |1     |55 |10    |74291.89 |1            |0        |1             |173561.33      |1.0            |
# |66657044  |468        |0        |1     |80 |9     |231541.49|2            |1        |1             |195891.96      |1.0            |
# |79338271  |564        |0        |1     |26 |8     |183856.24|4            |0        |0             |28945.94       |1.0            |
# |69616249  |819        |1        |0     |79 |4     |155550.9 |3            |0        |0             |183424.21      |1.0            |
# |69251239  |410        |2        |1     |23 |5     |27362.13 |1            |1        |1             |59652.75       |1.0            |
# |45375935  |658        |1        |0     |26 |4     |207902.85|2            |1        |0             |198977.54      |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# only showing top 20 rows
#
# Sent to Kafka: {'CustomerId': 87533838, 'CreditScore': 462, 'Geography': 0, 'Gender': 1, 'Age': 65, 'Tenure': 2, 'Balance': 62606.45, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 66910.92, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 13514980, 'CreditScore': 614, 'Geography': 0, 'Gender': 1, 'Age': 23, 'Tenure': 5, 'Balance': 49103.8, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 182883.44, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 76449385, 'CreditScore': 505, 'Geography': 0, 'Gender': 1, 'Age': 31, 'Tenure': 4, 'Balance': 205059.78, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 12350.26, 'ChurnPrediction': 0}
# Sent to Kafka: {'CustomerId': 41040408, 'CreditScore': 363, 'Geography': 0, 'Gender': 0, 'Age': 62, 'Tenure': 2, 'Balance': 40101.19, 'NumOfProducts': 2, 'HasCrCard': 0, 'IsActiveMember': 1, 'EstimatedSalary': 160262.94, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 49519398, 'CreditScore': 582, 'Geography': 2, 'Gender': 0, 'Age': 62, 'Tenure': 4, 'Balance': 219977.02, 'NumOfProducts': 1, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 119449.28, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 99598380, 'CreditScore': 726, 'Geography': 1, 'Gender': 0, 'Age': 66, 'Tenure': 8, 'Balance': 237201.15, 'NumOfProducts': 1, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 89849.54, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 25889310, 'CreditScore': 708, 'Geography': 2, 'Gender': 0, 'Age': 51, 'Tenure': 3, 'Balance': 243046.79, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 68309.95, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 20273885, 'CreditScore': 425, 'Geography': 1, 'Gender': 0, 'Age': 19, 'Tenure': 7, 'Balance': 29737.31, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 31955.93, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 26306118, 'CreditScore': 752, 'Geography': 1, 'Gender': 0, 'Age': 49, 'Tenure': 10, 'Balance': 141197.79, 'NumOfProducts': 3, 'HasCrCard': 0, 'IsActiveMember': 1, 'EstimatedSalary': 161599.28, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 87825317, 'CreditScore': 475, 'Geography': 2, 'Gender': 1, 'Age': 63, 'Tenure': 6, 'Balance': 149286.19, 'NumOfProducts': 4, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 160950.81, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 69702400, 'CreditScore': 389, 'Geography': 2, 'Gender': 1, 'Age': 25, 'Tenure': 3, 'Balance': 234800.23, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 78881.05, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 68817522, 'CreditScore': 738, 'Geography': 1, 'Gender': 0, 'Age': 18, 'Tenure': 4, 'Balance': 98946.94, 'NumOfProducts': 2, 'HasCrCard': 0, 'IsActiveMember': 1, 'EstimatedSalary': 68981.8, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 88967499, 'CreditScore': 530, 'Geography': 0, 'Gender': 0, 'Age': 25, 'Tenure': 3, 'Balance': 210612.31, 'NumOfProducts': 4, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 57463.11, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId':
 'NumOfProducts': 3, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 144999.42, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 36173990, 'CreditScore': 500, 'Geography': 0, 'Gender': 1, 'Age': 76, 'Tenure': 1, 'Balance': 57945.95, 'NumOfProducts': 1, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 187692.4, 'ChurnPrediction': 1}
# Sent to Kafka: {'CustomerId': 60360153, 'CreditScore': 795, 'Geography': 1, 'Gender': 0, 'Age': 67, 'Tenure': 1, 'Balance': 172240.33, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 79119.72, 'ChurnPrediction': 1}
# ...
#
# Sent to Kafka: {'CustomerId': 49917868, 'CreditScore': 591, 'Geography': 1, 'Gender': 0, 'Age': 72, 'Tenure': 5, 'Balance': 77930.39, 'NumOfProducts': 3, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 169294.95, 'ChurnPrediction': 1}
# Batch 3:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |45432975  |554        |0        |1     |56 |6     |132982.42|3            |0        |0             |95796.14       |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 45432975, 'CreditScore': 554, 'Geography': 0, 'Gender': 1, 'Age': 56, 'Tenure': 6, 'Balance': 132982.42, 'NumOfProducts': 3, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 95796.14, 'ChurnPrediction': 1}
# Batch 4:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |98419429  |737        |0        |1     |52 |10    |37948.35|2            |0        |1             |176893.51      |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 98419429, 'CreditScore': 737, 'Geography': 0, 'Gender': 1, 'Age': 52, 'Tenure': 10, 'Balance': 37948.35, 'NumOfProducts': 2, 'HasCrCard': 0, 'IsActiveMember': 1, 'EstimatedSalary': 176893.51, 'ChurnPrediction': 1}
# Batch 5:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |98381440  |384        |1        |0     |60 |5     |155399.5|2            |1        |1             |144093.72      |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 98381440, 'CreditScore': 384, 'Geography': 1, 'Gender': 0, 'Age': 60, 'Tenure': 5, 'Balance': 155399.5, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 144093.72, 'ChurnPrediction': 1}
# Batch 6:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |84223054  |624        |1        |0     |46 |10    |120161.76|1            |1        |1             |31584.16       |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 84223054, 'CreditScore': 624, 'Geography': 1, 'Gender': 0, 'Age': 46, 'Tenure': 10, 'Balance': 120161.76, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 31584.16, 'ChurnPrediction': 1}
# Batch 7:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |50226644  |382        |2        |0     |36 |9     |97491.44|3            |1        |1             |129425.61      |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 50226644, 'CreditScore': 382, 'Geography': 2, 'Gender': 0, 'Age': 36, 'Tenure': 9, 'Balance': 97491.44, 'NumOfProducts': 3, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 129425.61, 'ChurnPrediction': 1}
# Batch 8:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |50223869  |566        |2        |0     |27 |8     |179668.14|4            |1        |1             |44477.86       |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 50223869, 'CreditScore': 566, 'Geography': 2, 'Gender': 0, 'Age': 27, 'Tenure': 8, 'Balance': 179668.14, 'NumOfProducts': 4, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 44477.86, 'ChurnPrediction': 1}
# Batch 9:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |49569116  |686        |0        |0     |51 |5     |240417.77|1            |1        |0             |59739.71       |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 49569116, 'CreditScore': 686, 'Geography': 0, 'Gender': 0, 'Age': 51, 'Tenure': 5, 'Balance': 240417.77, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 59739.71, 'ChurnPrediction': 1}
# Batch 10:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |83221389  |730        |2        |1     |73 |7     |91100.91|4            |1        |1             |107002.71      |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 83221389, 'CreditScore': 730, 'Geography': 2, 'Gender': 1, 'Age': 73, 'Tenure': 7, 'Balance': 91100.91, 'NumOfProducts': 4, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 107002.71, 'ChurnPrediction': 1}
# Batch 11:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |13401998  |412        |0        |1     |65 |1     |158478.97|3            |0        |1             |13319.77       |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 13401998, 'CreditScore': 412, 'Geography': 0, 'Gender': 1, 'Age': 65, 'Tenure': 1, 'Balance': 158478.97, 'NumOfProducts': 3, 'HasCrCard': 0, 'IsActiveMember': 1, 'EstimatedSalary': 13319.77, 'ChurnPrediction': 1}
# Batch 12:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |90910188  |517        |2        |0     |73 |6     |103045.32|3            |0        |1             |120545.35      |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 90910188, 'CreditScore': 517, 'Geography': 2, 'Gender': 0, 'Age': 73, 'Tenure': 6, 'Balance': 103045.32, 'NumOfProducts': 3, 'HasCrCard': 0, 'IsActiveMember': 1, 'EstimatedSalary': 120545.35, 'ChurnPrediction': 1}
# Batch 13:
# +----------+-----------+---------+------+---+------+-------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance|NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+-------+-------------+---------+--------------+---------------+---------------+
# |95317130  |692        |1        |1     |25 |9     |57913.3|2            |1        |1             |191652.75      |1.0            |
# +----------+-----------+---------+------+---+------+-------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 95317130, 'CreditScore': 692, 'Geography': 1, 'Gender': 1, 'Age': 25, 'Tenure': 9, 'Balance': 57913.3, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 191652.75, 'ChurnPrediction': 1}
# Batch 14:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |86342361  |403        |1        |0     |42 |8     |133447.9|4            |0        |0             |163116.2       |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 86342361, 'CreditScore': 403, 'Geography': 1, 'Gender': 0, 'Age': 42, 'Tenure': 8, 'Balance': 133447.9, 'NumOfProducts': 4, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 163116.2, 'ChurnPrediction': 1}
# Batch 15:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |30663151  |794        |1        |1     |25 |7     |87270.98|2            |1        |0             |38611.11       |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 30663151, 'CreditScore': 794, 'Geography': 1, 'Gender': 1, 'Age': 25, 'Tenure': 7, 'Balance': 87270.98, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 38611.11, 'ChurnPrediction': 1}
# Batch 16:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |66143172  |810        |1        |1     |60 |8     |204121.13|2            |0        |0             |177195.14      |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 66143172, 'CreditScore': 810, 'Geography': 1, 'Gender': 1, 'Age': 60, 'Tenure': 8, 'Balance': 204121.13, 'NumOfProducts': 2, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 177195.14, 'ChurnPrediction': 1}
# Batch 17:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |15227178  |748        |1        |1     |80 |4     |49063.45|4            |1        |0             |127368.92      |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 15227178, 'CreditScore': 748, 'Geography': 1, 'Gender': 1, 'Age': 80, 'Tenure': 4, 'Balance': 49063.45, 'NumOfProducts': 4, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 127368.92, 'ChurnPrediction': 1}
# Batch 18:
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
# |10755346  |517        |0        |1     |72 |4     |201051.78|4            |0        |0             |192212.9       |1.0            |
# +----------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 10755346, 'CreditScore': 517, 'Geography': 0, 'Gender': 1, 'Age': 72, 'Tenure': 4, 'Balance': 201051.78, 'NumOfProducts': 4, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 192212.9, 'ChurnPrediction': 1}
# Batch 19:
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |CustomerId|CreditScore|Geography|Gender|Age|Tenure|Balance |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|ChurnPrediction|
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
# |88836081  |538        |0        |1     |63 |7     |19978.42|3            |0        |0             |19255.0        |1.0            |
# +----------+-----------+---------+------+---+------+--------+-------------+---------+--------------+---------------+---------------+
#
# Sent to Kafka: {'CustomerId': 88836081, 'CreditScore': 538, 'Geography': 0, 'Gender': 1, 'Age': 63, 'Tenure': 7, 'Balance': 19978.42, 'NumOfProducts': 3, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 19255.0, 'ChurnPrediction': 1}
