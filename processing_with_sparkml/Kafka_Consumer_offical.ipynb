# %%
import sys
import os
import json
import numpy as np
import pandas as pd
from kafka import KafkaProducer
import pg8000
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, from_json
from pyspark.sql.types import *
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import RandomForestClassificationModel

# Cấu hình môi trường PySpark
os.environ["PYSPARK_PYTHON"] = "c:/Users/PC/Desktop/Do_an_Big_data/PythonCodes/henv/Scripts/python.exe"
os.environ["PYSPARK_DRIVER_PYTHON"] = os.environ["PYSPARK_PYTHON"]

# Khởi tạo SparkSession
def init_spark():
    return SparkSession.builder \
        .master("local") \
        .appName("ChurnPredictionStreaming") \
        .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.2.1") \
        .config("spark.sql.shuffle.partitions", "1") \
        .getOrCreate()

# Định nghĩa schema cho dữ liệu đầu vào
schema = StructType([
    StructField("CustomerId", IntegerType(), True),
    StructField("Surname", StringType(), True),
    StructField("CreditScore", IntegerType(), True),
    StructField("Age", IntegerType(), True),
    StructField("Tenure", IntegerType(), True),
    StructField("Balance", DoubleType(), True),
    StructField("NumOfProducts", IntegerType(), True),
    StructField("HasCrCard", IntegerType(), True),
    StructField("IsActiveMember", IntegerType(), True),
    StructField("EstimatedSalary", DoubleType(), True),
    StructField("BalanceSalary", DoubleType(), True),
    StructField("TenureAge", DoubleType(), True),
    StructField("ScoreAge", DoubleType(), True),
    StructField("tenure_age", DoubleType(), True),
    StructField("tenure_salary", DoubleType(), True),
    StructField("score_age", DoubleType(), True),
    StructField("score_salary", DoubleType(), True),
    StructField("newAge", IntegerType(), True),
    StructField("newCreditScore", IntegerType(), True),
    StructField("AgeScore", IntegerType(), True),
    StructField("BalanceScore", IntegerType(), True),
    StructField("SalaryScore", IntegerType(), True),
    StructField("newEstimatedSalary", DoubleType(), True),
    StructField("score_balance", DoubleType(), True),
    StructField("age_balance", DoubleType(), True),
    StructField("balance_salary", DoubleType(), True),
    StructField("age_hascrcard", DoubleType(), True),
    StructField("product_utilization_rate_by_year", DoubleType(), True),
    StructField("product_utilization_rate_by_salary", DoubleType(), True),
    StructField("countries_monthly_average_salaries", DoubleType(), True),
    StructField("Germany", BooleanType(), True),
    StructField("Spain", BooleanType(), True),
    StructField("Female", BooleanType(), True),
    StructField("Male", BooleanType(), True)
])

# Class để load mô hình Random Forest
class ModelLoader:
    MODEL_PATH = "C:/Users/PC/Desktop/Do_an_Big_data/PythonCodes/work/models/random_forest_on_sparkml"
    
    def __init__(self, spark):
        self.model = RandomForestClassificationModel.load(self.MODEL_PATH)

# Cấu hình Kafka Producer
def init_kafka_producer():
    return KafkaProducer(
        bootstrap_servers='localhost:9092',
        value_serializer=lambda v: json.dumps(v).encode('utf-8'),
        acks='all',
        retries=3
    )

# Cấu hình PostgreSQL
PG_CONFIG = {
    "host": "localhost",
    "user": "postgres",
    "password": "1234",
    "database": "churn_prediction",
    "port": 5432
}
TABLE_NAME = "churn_prediction"

from pyspark.ml.feature import StandardScaler

# Hàm xử lý batch dữ liệu streaming
def process_batch(spark, model_loader, producer):
    # Đọc dữ liệu từ Kafka
    kafka_df = spark.readStream.format("kafka") \
        .option("kafka.bootstrap.servers", "localhost:9092") \
        .option("subscribe", "producerrf_sparkml") \
        .load()

    # Parse dữ liệu JSON theo schema
    parsed_df = kafka_df.selectExpr("CAST(value AS STRING) as raw_data") \
        .select(from_json(col("raw_data"), schema).alias("data")).select("data.*")

    # Hàm xử lý từng batch
    def process(batch_df, batch_id):
        try:
            if batch_df.count() == 0:
                print(f"Batch {batch_id}: No data")
                return

            # Chuyển đổi các cột boolean thành integer
            boolean_cols = ["Germany", "Spain", "Female", "Male"]
            for col_name in boolean_cols:
                batch_df = batch_df.withColumn(col_name, col(col_name).cast("int"))

            # Chọn các cột feature (loại bỏ CustomerId và Surname)
            feature_cols = [c for c in batch_df.columns if c not in ["CustomerId", "Surname"]]
            df_filled = batch_df.fillna(0)

            # Tạo vector features
            assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
            df_features = assembler.transform(df_filled)

            # Chuẩn hóa dữ liệu để tạo cột "scaled_features"
            scaler = StandardScaler(inputCol="features", outputCol="scaled_features", withStd=True, withMean=True)
            scaler_model = scaler.fit(df_features)
            df_scaled = scaler_model.transform(df_features)

            # Dự đoán bằng mô hình Random Forest
            df_result = model_loader.model.transform(df_scaled) \
                .withColumn("ChurnPrediction", col("prediction")) \
                .drop("features", "scaled_features", "rawPrediction", "probability", "prediction")

            # Gửi kết quả đi
            send_to_kafka_and_db(df_result, batch_id, producer)
            
            print(f"Batch {batch_id} processed successfully")
            df_result.show(5, truncate=False)

        except Exception as e:
            print(f"Error in batch {batch_id}: {str(e)}")

    return parsed_df.writeStream \
        .foreachBatch(process) \
        .outputMode("append") \
        .start()

# Hàm gửi kết quả đến Kafka và PostgreSQL
def send_to_kafka_and_db(df, batch_id, producer):
    try:
        conn = pg8000.connect(**PG_CONFIG)
        cursor = conn.cursor()
        
        # Lấy danh sách cột từ schema (giữ nguyên tên gốc, ví dụ 'ChurnPrediction')
        original_columns = [field.name for field in schema.fields] + ["ChurnPrediction"]
        
        # Danh sách cột cho PostgreSQL (chuyển thành chữ thường)
        lowercase_columns = [col.lower() for col in original_columns]
        
        # Chuyển DataFrame thành danh sách các bản ghi
        records = df.collect()
        
        # Print thông tin batch
        print(f"Processing batch {batch_id} with {len(records)} records")

        for row in records:
            # Chuyển row thành dictionary với tên cột gốc (giữ nguyên chữ hoa)
            message = {col: row[col] for col in row.asDict().keys()}
            
            # Gửi đến Kafka với tên cột gốc
            producer.send("prediction_rf_sparkml", value=message)
            
            # Print dữ liệu trước khi gửi vào Kafka
            print(f"Batch {batch_id} - Sending to Kafka: {message}")
            
            # Chuyển tên cột thành chữ thường cho PostgreSQL
            lowercase_message = {col.lower(): row[col] for col in row.asDict().keys()}
            
            # Chuẩn bị giá trị cho PostgreSQL (sử dụng tên cột chữ thường)
            values = tuple(lowercase_message.get(col, None) for col in lowercase_columns)
            
            # Print giá trị trước khi gửi vào PostgreSQL
            print(f"Batch {batch_id} - Values to PostgreSQL: {values}")
            
            # Tạo câu lệnh SQL với tên cột chữ thường
            placeholders = ','.join(['%s'] * len(lowercase_columns))
            sql = f"INSERT INTO {TABLE_NAME} ({','.join(lowercase_columns)}) VALUES ({placeholders})"
            cursor.execute(sql, values)

        conn.commit()
        print(f"Batch {batch_id} saved to Kafka and PostgreSQL")
        
    except Exception as e:
        print(f"Error saving batch {batch_id}: {str(e)}")
    finally:
        if 'cursor' in locals():
            cursor.close()
        if 'conn' in locals():
            conn.close()

# Hàm main
def main():
    # Khởi tạo Spark và các component
    spark = init_spark()
    model_loader = ModelLoader(spark)
    producer = init_kafka_producer()
    
    # Bắt đầu xử lý stream
    query = process_batch(spark, model_loader, producer)
    try:
        query.awaitTermination()
    except KeyboardInterrupt:
        query.stop()
    finally:
        producer.close()
        spark.stop()

if __name__ == "__main__":
    main()
# Out:
# Batch 0: No data
# Processing batch 1 with 1 records
# Batch 1 - Sending to Kafka: {'CustomerId': 15631848, 'Surname': 'Grover', 'CreditScore': 727, 'Age': 26, 'Tenure': 9, 'Balance': 121508.28, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 146785.44, 'BalanceSalary': 0.827795182, 'TenureAge': 0.346153846, 'ScoreAge': 27.96153846, 'tenure_age': 1.0, 'tenure_salary': 6.13e-05, 'score_age': 80.77777778, 'score_salary': 0.004952807, 'newAge': 17, 'newCreditScore': 8, 'AgeScore': 1, 'BalanceScore': 7, 'SalaryScore': 8, 'newEstimatedSalary': 12232.12, 'score_balance': 167.1365612, 'age_balance': 4673.395385, 'balance_salary': 0.827795182, 'age_hascrcard': 0.038461538, 'product_utilization_rate_by_year': 0.111111111, 'product_utilization_rate_by_salary': 6.81e-06, 'countries_monthly_average_salaries': 3.309556277, 'Germany': 0, 'Spain': 0, 'Female': 1, 'Male': 0, 'ChurnPrediction': 0.0}
# Batch 1 - Values to PostgreSQL: (15631848, 'Grover', 727, 26, 9, 121508.28, 1, 1, 1, 146785.44, 0.827795182, 0.346153846, 27.96153846, 1.0, 6.13e-05, 80.77777778, 0.004952807, 17, 8, 1, 7, 8, 12232.12, 167.1365612, 4673.395385, 0.827795182, 0.038461538, 0.111111111, 6.81e-06, 3.309556277, 0, 0, 1, 0, 0.0)
# Batch 1 saved to Kafka and PostgreSQL
# Batch 1 processed successfully
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname|CreditScore|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge  |ScoreAge   |tenure_age|tenure_salary|score_age  |score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15631848  |Grover |727        |26 |9     |121508.28|1            |1        |1             |146785.44      |0.827795182  |0.346153846|27.96153846|1.0       |6.13E-5      |80.77777778|0.004952807 |17    |8             |1       |7           |8          |12232.12          |167.1365612  |4673.395385|0.827795182   |0.038461538  |0.111111111                     |6.81E-6                           |3.309556277                       |0      |0    |1     |0   |0.0            |
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
#
# Processing batch 2 with 2 records
# Batch 2 - Sending to Kafka: {'CustomerId': 15634491, 'Surname': 'Kung', 'CreditScore': 652, 'Age': 30, 'Tenure': 2, 'Balance': 176166.56, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 152210.81, 'BalanceSalary': 1.157385339, 'TenureAge': 0.066666667, 'ScoreAge': 21.73333333, 'tenure_age': 0.153846154, 'tenure_salary': 1.31e-05, 'score_age': 50.15384615, 'score_salary': 0.004283533, 'newAge': 28, 'newCreditScore': 5, 'AgeScore': 2, 'BalanceScore': 10, 'SalaryScore': 8, 'newEstimatedSalary': 12684.23417, 'score_balance': 270.1941104, 'age_balance': 5872.218667, 'balance_salary': 1.157385339, 'age_hascrcard': 0.033333333, 'product_utilization_rate_by_year': 1.0, 'product_utilization_rate_by_salary': 1.31e-05, 'countries_monthly_average_salaries': 3.431881539, 'Germany': 0, 'Spain': 0, 'Female': 0, 'Male': 1, 'ChurnPrediction': 0.0}
# Batch 2 - Values to PostgreSQL: (15634491, 'Kung', 652, 30, 2, 176166.56, 2, 1, 1, 152210.81, 1.157385339, 0.066666667, 21.73333333, 0.153846154, 1.31e-05, 50.15384615, 0.004283533, 28, 5, 2, 10, 8, 12684.23417, 270.1941104, 5872.218667, 1.157385339, 0.033333333, 1.0, 1.31e-05, 3.431881539, 0, 0, 0, 1, 0.0)
# Batch 2 - Sending to Kafka: {'CustomerId': 15605455, 'Surname': 'Tai', 'CreditScore': 664, 'Age': 40, 'Tenure': 9, 'Balance': 0.0, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 194767.3, 'BalanceSalary': 0.0, 'TenureAge': 0.225, 'ScoreAge': 16.6, 'tenure_age': 0.391304348, 'tenure_salary': 4.62e-05, 'score_age': 28.86956522, 'score_salary': 0.003409197, 'newAge': 31, 'newCreditScore': 6, 'AgeScore': 5, 'BalanceScore': 3, 'SalaryScore': 10, 'newEstimatedSalary': 16230.60833, 'score_balance': 0.0, 'age_balance': 0.0, 'balance_salary': 0.0, 'age_hascrcard': 0.025, 'product_utilization_rate_by_year': 0.222222222, 'product_utilization_rate_by_salary': 1.03e-05, 'countries_monthly_average_salaries': 4.391398359, 'Germany': 0, 'Spain': 0, 'Female': 0, 'Male': 1, 'ChurnPrediction': 1.0}
# Batch 2 - Values to PostgreSQL: (15605455, 'Tai', 664, 40, 9, 0.0, 2, 1, 0, 194767.3, 0.0, 0.225, 16.6, 0.391304348, 4.62e-05, 28.86956522, 0.003409197, 31, 6, 5, 3, 10, 16230.60833, 0.0, 0.0, 0.0, 0.025, 0.222222222, 1.03e-05, 4.391398359, 0, 0, 0, 1, 1.0)
# Batch 2 saved to Kafka and PostgreSQL
# Batch 2 processed successfully
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname|CreditScore|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge  |ScoreAge   |tenure_age |tenure_salary|score_age  |score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15634491  |Kung   |652        |30 |2     |176166.56|2            |1        |1             |152210.81      |1.157385339  |0.066666667|21.73333333|0.153846154|1.31E-5      |50.15384615|0.004283533 |28    |5             |2       |10          |8          |12684.23417       |270.1941104  |5872.218667|1.157385339   |0.033333333  |1.0                             |1.31E-5                           |3.431881539                       |0      |0    |0     |1   |0.0            |
# |15605455  |Tai    |664        |40 |9     |0.0      |2            |1        |0             |194767.3       |0.0          |0.225      |16.6       |0.391304348|4.62E-5      |28.86956522|0.003409197 |31    |6             |5       |3           |10         |16230.60833       |0.0          |0.0        |0.0           |0.025        |0.222222222                     |1.03E-5                           |4.391398359                       |0      |0    |0     |1   |1.0            |
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
#
# Processing batch 3 with 1 records
# Batch 3 - Sending to Kafka: {'CustomerId': 15745324, 'Surname': 'Milani', 'CreditScore': 599, 'Age': 39, 'Tenure': 4, 'Balance': 0.0, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 194273.2, 'BalanceSalary': 0.0, 'TenureAge': 0.102564103, 'ScoreAge': 15.35897436, 'tenure_age': 0.181818182, 'tenure_salary': 2.06e-05, 'score_age': 27.22727273, 'score_salary': 0.003083287, 'newAge': 35, 'newCreditScore': 4, 'AgeScore': 5, 'BalanceScore': 1, 'SalaryScore': 10, 'newEstimatedSalary': 16189.43333, 'score_balance': 0.0, 'age_balance': 0.0, 'balance_salary': 0.0, 'age_hascrcard': 0.025641026, 'product_utilization_rate_by_year': 0.25, 'product_utilization_rate_by_salary': 5.15e-06, 'countries_monthly_average_salaries': 7.172987742, 'Germany': 0, 'Spain': 1, 'Female': 1, 'Male': 0, 'ChurnPrediction': 0.0}
# Batch 3 - Values to PostgreSQL: (15745324, 'Milani', 599, 39, 4, 0.0, 1, 1, 0, 194273.2, 0.0, 0.102564103, 15.35897436, 0.181818182, 2.06e-05, 27.22727273, 0.003083287, 35, 4, 5, 1, 10, 16189.43333, 0.0, 0.0, 0.0, 0.025641026, 0.25, 5.15e-06, 7.172987742, 0, 1, 1, 0, 0.0)
# Batch 3 saved to Kafka and PostgreSQL
# Batch 3 processed successfully
# +----------+-------+-----------+---+------+-------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname|CreditScore|Age|Tenure|Balance|NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge  |ScoreAge   |tenure_age |tenure_salary|score_age  |score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+-------+-----------+---+------+-------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15745324  |Milani |599        |39 |4     |0.0    |1            |1        |0             |194273.2       |0.0          |0.102564103|15.35897436|0.181818182|2.06E-5      |27.22727273|0.003083287 |35    |4             |5       |1           |10         |16189.43333       |0.0          |0.0        |0.0           |0.025641026  |0.25                            |5.15E-6                           |7.172987742                       |0      |1    |1     |0   |0.0            |
# +----------+-------+-----------+---+------+-------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
#
# Processing batch 4 with 1 records
# Batch 4 - Sending to Kafka: {'CustomerId': 15619972, 'Surname': 'Akabueze', 'CreditScore': 807, 'Age': 47, 'Tenure': 9, 'Balance': 167664.83, 'NumOfProducts': 1, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 125440.11, 'BalanceSalary': 1.336612587, 'TenureAge': 0.191489362, 'ScoreAge': 17.17021277, 'tenure_age': 0.3, 'tenure_salary': 7.17e-05, 'score_age': 26.9, 'score_salary': 0.006433349, 'newAge': 38, 'newCreditScore': 10, 'AgeScore': 7, 'BalanceScore': 10, 'SalaryScore': 7, 'newEstimatedSalary': 10453.3425, 'score_balance': 207.7631103, 'age_balance': 3567.336809, 'balance_salary': 1.336612587, 'age_hascrcard': 0.0, 'product_utilization_rate_by_year': 0.111111111, 'product_utilization_rate_by_salary': 7.97e-06, 'countries_monthly_average_salaries': 2.828285308, 'Germany': 0, 'Spain': 0, 'Female': 1, 'Male': 0, 'ChurnPrediction': 0.0}
# Batch 4 - Values to PostgreSQL: (15619972, 'Akabueze', 807, 47, 9, 167664.83, 1, 0, 0, 125440.11, 1.336612587, 0.191489362, 17.17021277, 0.3, 7.17e-05, 26.9, 0.006433349, 38, 10, 7, 10, 7, 10453.3425, 207.7631103, 3567.336809, 1.336612587, 0.0, 0.111111111, 7.97e-06, 2.828285308, 0, 0, 1, 0, 0.0)
# Batch 4 saved to Kafka and PostgreSQL
# Batch 4 processed successfully
# +----------+--------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname |CreditScore|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge  |ScoreAge   |tenure_age|tenure_salary|score_age|score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+--------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15619972  |Akabueze|807        |47 |9     |167664.83|1            |0        |0             |125440.11      |1.336612587  |0.191489362|17.17021277|0.3       |7.17E-5      |26.9     |0.006433349 |38    |10            |7       |10          |7          |10453.3425        |207.7631103  |3567.336809|1.336612587   |0.0          |0.111111111                     |7.97E-6                           |2.828285308                       |0      |0    |1     |0   |0.0            |
# +----------+--------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
#
# Processing batch 5 with 1 records
# Batch 5 - Sending to Kafka: {'CustomerId': 15693864, 'Surname': 'Iheanacho', 'CreditScore': 567, 'Age': 49, 'Tenure': 5, 'Balance': 134956.02, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 93953.84, 'BalanceSalary': 1.436407708, 'TenureAge': 0.102040816, 'ScoreAge': 11.57142857, 'tenure_age': 0.15625, 'tenure_salary': 5.32e-05, 'score_age': 17.71875, 'score_salary': 0.006034878, 'newAge': 44, 'newCreditScore': 3, 'AgeScore': 8, 'BalanceScore': 9, 'SalaryScore': 5, 'newEstimatedSalary': 7829.486667, 'score_balance': 238.017672, 'age_balance': 2754.20449, 'balance_salary': 1.436407708, 'age_hascrcard': 0.020408163, 'product_utilization_rate_by_year': 0.2, 'product_utilization_rate_by_salary': 1.06e-05, 'countries_monthly_average_salaries': 1.651790436, 'Germany': 1, 'Spain': 0, 'Female': 1, 'Male': 0, 'ChurnPrediction': 0.0}
# Batch 5 - Values to PostgreSQL: (15693864, 'Iheanacho', 567, 49, 5, 134956.02, 1, 1, 0, 93953.84, 1.436407708, 0.102040816, 11.57142857, 0.15625, 5.32e-05, 17.71875, 0.006034878, 44, 3, 8, 9, 5, 7829.486667, 238.017672, 2754.20449, 1.436407708, 0.020408163, 0.2, 1.06e-05, 1.651790436, 1, 0, 1, 0, 0.0)
# Batch 5 saved to Kafka and PostgreSQL
# Batch 5 processed successfully
# +----------+---------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname  |CreditScore|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge  |ScoreAge   |tenure_age|tenure_salary|score_age|score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+---------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15693864  |Iheanacho|567        |49 |5     |134956.02|1            |1        |0             |93953.84       |1.436407708  |0.102040816|11.57142857|0.15625   |5.32E-5      |17.71875 |0.006034878 |44    |3             |8       |9           |5          |7829.486667       |238.017672   |2754.20449 |1.436407708   |0.020408163  |0.2                             |1.06E-5                           |1.651790436                       |1      |0    |1     |0   |0.0            |
# +----------+---------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
#
# Processing batch 6 with 2 records
# Batch 6 - Sending to Kafka: {'CustomerId': 15804814, 'Surname': "Ts'ui", 'CreditScore': 759, 'Age': 40, 'Tenure': 4, 'Balance': 0.0, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 0, 'EstimatedSalary': 124615.59, 'BalanceSalary': 0.0, 'TenureAge': 0.1, 'ScoreAge': 18.975, 'tenure_age': 0.173913043, 'tenure_salary': 3.21e-05, 'score_age': 33.0, 'score_salary': 0.006090731, 'newAge': 36, 'newCreditScore': 9, 'AgeScore': 5, 'BalanceScore': 1, 'SalaryScore': 7, 'newEstimatedSalary': 10384.6325, 'score_balance': 0.0, 'age_balance': 0.0, 'balance_salary': 0.0, 'age_hascrcard': 0.025, 'product_utilization_rate_by_year': 0.5, 'product_utilization_rate_by_salary': 1.6e-05, 'countries_monthly_average_salaries': 2.80969494, 'Germany': 0, 'Spain': 0, 'Female': 0, 'Male': 1, 'ChurnPrediction': 1.0}
# Batch 6 - Values to PostgreSQL: (15804814, "Ts'ui", 759, 40, 4, 0.0, 2, 1, 0, 124615.59, 0.0, 0.1, 18.975, 0.173913043, 3.21e-05, 33.0, 0.006090731, 36, 9, 5, 1, 7, 10384.6325, 0.0, 0.0, 0.0, 0.025, 0.5, 1.6e-05, 2.80969494, 0, 0, 0, 1, 1.0)
# Batch 6 - Sending to Kafka: {'CustomerId': 15590337, 'Surname': 'Golubov', 'CreditScore': 659, 'Age': 29, 'Tenure': 6, 'Balance': 123192.12, 'NumOfProducts': 1, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 56971.41, 'BalanceSalary': 2.162349852, 'TenureAge': 0.206896552, 'ScoreAge': 22.72413793, 'tenure_age': 0.5, 'tenure_salary': 0.000105316, 'score_age': 54.91666667, 'score_salary': 0.011567205, 'newAge': 23, 'newCreditScore': 6, 'AgeScore': 2, 'BalanceScore': 8, 'SalaryScore': 3, 'newEstimatedSalary': 4747.6175, 'score_balance': 186.9379666, 'age_balance': 4248.004138, 'balance_salary': 2.162349852, 'age_hascrcard': 0.034482759, 'product_utilization_rate_by_year': 0.166666667, 'product_utilization_rate_by_salary': 1.76e-05, 'countries_monthly_average_salaries': 1.284528544, 'Germany': 0, 'Spain': 0, 'Female': 0, 'Male': 1, 'ChurnPrediction': 0.0}
# Batch 6 - Values to PostgreSQL: (15590337, 'Golubov', 659, 29, 6, 123192.12, 1, 1, 1, 56971.41, 2.162349852, 0.206896552, 22.72413793, 0.5, 0.000105316, 54.91666667, 0.011567205, 23, 6, 2, 8, 3, 4747.6175, 186.9379666, 4248.004138, 2.162349852, 0.034482759, 0.166666667, 1.76e-05, 1.284528544, 0, 0, 0, 1, 0.0)
# Batch 6 saved to Kafka and PostgreSQL
# Batch 6 processed successfully
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname|CreditScore|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge  |ScoreAge   |tenure_age |tenure_salary|score_age  |score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15804814  |Ts'ui  |759        |40 |4     |0.0      |2            |1        |0             |124615.59      |0.0          |0.1        |18.975     |0.173913043|3.21E-5      |33.0       |0.006090731 |36    |9             |5       |1           |7          |10384.6325        |0.0          |0.0        |0.0           |0.025        |0.5                             |1.6E-5                            |2.80969494                        |0      |0    |0     |1   |1.0            |
# |15590337  |Golubov|659        |29 |6     |123192.12|1            |1        |1             |56971.41       |2.162349852  |0.206896552|22.72413793|0.5        |1.05316E-4   |54.91666667|0.011567205 |23    |6             |2       |8           |3          |4747.6175         |186.9379666  |4248.004138|2.162349852   |0.034482759  |0.166666667                     |1.76E-5                           |1.284528544                       |0      |0    |0     |1   |0.0            |
# +----------+-------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+-----------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
#
# Processing batch 7 with 1 records
# Batch 7 - Sending to Kafka: {'CustomerId': 15706762, 'Surname': 'Ignatyev', 'CreditScore': 597, 'Age': 41, 'Tenure': 4, 'Balance': 145809.53, 'NumOfProducts': 2, 'HasCrCard': 1, 'IsActiveMember': 1, 'EstimatedSalary': 52319.26, 'BalanceSalary': 2.786918813, 'TenureAge': 0.097560976, 'ScoreAge': 14.56097561, 'tenure_age': 0.166666667, 'tenure_salary': 7.65e-05, 'score_age': 24.875, 'score_salary': 0.011410712, 'newAge': 37, 'newCreditScore': 3, 'AgeScore': 6, 'BalanceScore': 9, 'SalaryScore': 3, 'newEstimatedSalary': 4359.938333, 'score_balance': 244.2370687, 'age_balance': 3556.33, 'balance_salary': 2.786918813, 'age_hascrcard': 0.024390244, 'product_utilization_rate_by_year': 0.5, 'product_utilization_rate_by_salary': 3.82e-05, 'countries_monthly_average_salaries': 1.179636995, 'Germany': 0, 'Spain': 0, 'Female': 1, 'Male': 0, 'ChurnPrediction': 0.0}
# Batch 7 - Values to PostgreSQL: (15706762, 'Ignatyev', 597, 41, 4, 145809.53, 2, 1, 1, 52319.26, 2.786918813, 0.097560976, 14.56097561, 0.166666667, 7.65e-05, 24.875, 0.011410712, 37, 3, 6, 9, 3, 4359.938333, 244.2370687, 3556.33, 2.786918813, 0.024390244, 0.5, 3.82e-05, 1.179636995, 0, 0, 1, 0, 0.0)
# Batch 7 saved to Kafka and PostgreSQL
# Batch 7 processed successfully
# +----------+--------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname |CreditScore|Age|Tenure|Balance  |NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge  |ScoreAge   |tenure_age |tenure_salary|score_age|score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+--------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15706762  |Ignatyev|597        |41 |4     |145809.53|2            |1        |1             |52319.26       |2.786918813  |0.097560976|14.56097561|0.166666667|7.65E-5      |24.875   |0.011410712 |37    |3             |6       |9           |3          |4359.938333       |244.2370687  |3556.33    |2.786918813   |0.024390244  |0.5                             |3.82E-5                           |1.179636995                       |0      |0    |1     |0   |0.0            |
# +----------+--------+-----------+---+------+---------+-------------+---------+--------------+---------------+-------------+-----------+-----------+-----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
#
# Processing batch 8 with 1 records
# Batch 8 - Sending to Kafka: {'CustomerId': 15765266, 'Surname': 'Fleming', 'CreditScore': 615, 'Age': 32, 'Tenure': 1, 'Balance': 0.0, 'NumOfProducts': 2, 'HasCrCard': 0, 'IsActiveMember': 0, 'EstimatedSalary': 2139.25, 'BalanceSalary': 0.0, 'TenureAge': 0.03125, 'ScoreAge': 19.21875, 'tenure_age': 0.066666667, 'tenure_salary': 0.000467454, 'score_age': 41.0, 'score_salary': 0.287483931, 'newAge': 31, 'newCreditScore': 4, 'AgeScore': 2, 'BalanceScore': 2, 'SalaryScore': 1, 'newEstimatedSalary': 178.2708333, 'score_balance': 0.0, 'age_balance': 0.0, 'balance_salary': 0.0, 'age_hascrcard': 0.0, 'product_utilization_rate_by_year': 2.0, 'product_utilization_rate_by_salary': 0.000934907, 'countries_monthly_average_salaries': 0.048233451, 'Germany': 0, 'Spain': 0, 'Female': 0, 'Male': 1, 'ChurnPrediction': 0.0}
# Batch 8 - Values to PostgreSQL: (15765266, 'Fleming', 615, 32, 1, 0.0, 2, 0, 0, 2139.25, 0.0, 0.03125, 19.21875, 0.066666667, 0.000467454, 41.0, 0.287483931, 31, 4, 2, 2, 1, 178.2708333, 0.0, 0.0, 0.0, 0.0, 2.0, 0.000934907, 0.048233451, 0, 0, 0, 1, 0.0)
# Batch 8 saved to Kafka and PostgreSQL
# Batch 8 processed successfully
# +----------+-------+-----------+---+------+-------+-------------+---------+--------------+---------------+-------------+---------+--------+-----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |CustomerId|Surname|CreditScore|Age|Tenure|Balance|NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|BalanceSalary|TenureAge|ScoreAge|tenure_age |tenure_salary|score_age|score_salary|newAge|newCreditScore|AgeScore|BalanceScore|SalaryScore|newEstimatedSalary|score_balance|age_balance|balance_salary|age_hascrcard|product_utilization_rate_by_year|product_utilization_rate_by_salary|countries_monthly_average_salaries|Germany|Spain|Female|Male|ChurnPrediction|
# +----------+-------+-----------+---+------+-------+-------------+---------+--------------+---------------+-------------+---------+--------+-----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
# |15765266  |Fleming|615        |32 |1     |0.0    |2            |0        |0             |2139.25        |0.0          |0.03125  |19.21875|0.066666667|4.67454E-4   |41.0     |0.287483931 |31    |4             |2       |2           |1          |178.2708333       |0.0          |0.0        |0.0           |0.0          |2.0                             |9.34907E-4                        |0.048233451                       |0      |0    |0     |1   |0.0            |
# +----------+-------+-----------+---+------+-------+-------------+---------+--------------+---------------+-------------+---------+--------+-----------+-------------+---------+------------+------+--------------+--------+------------+-----------+------------------+-------------+-----------+--------------+-------------+--------------------------------+----------------------------------+----------------------------------+-------+-----+------+----+---------------+
